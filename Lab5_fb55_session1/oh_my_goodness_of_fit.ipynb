# %% [markdown]
# # To test the difference between a Binomial/Poisson distribution and a Gaussian distribution as you change the parameters of the Binomial/Poisson. Use:
#
#     1) KS
#
#     2) KL or Chisq
#
#     3) AD
#
#     4) Pearson's chisq
#
#     I want you to use the scipy.stats package for this. It will provide tests. For KS and AD you will simply need to generate the distribution the normal will be tested agains: the KS and AD functions in scipy have functionality to test against standard distributions (normal, chisq etc) without you having to code up anything about the distribution itself. KL and chisq do not.

# %% [markdown]
# my usual imports and setups

# %%
import pylab as pl
import pandas as pd
import numpy as np
# %pylab inline

import os

#this makes my plots pretty! but it is totally not mandatory to do it
import json
s = json.load( open(os.getenv ('PUI2018')+"/fbb_matplotlibrc.json") )
pl.rcParams.update(s)

#plus importing scipy.stats
import scipy.stats
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# here are the manual pages fo the tests
#
# http://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kstest.html#scipy.stats.kstest
# http://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.anderson.html#scipy.stats.anderson
# http://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.entropy.html#scipy.stats.entropy

# %% [markdown]
# i need to figure out what each test function returns. let me run them once to see (and read the manual atthe same time!)
#
# i am testing for normal against normal and for a Poisson w small n*p against normal. that will give me very different outcomes. why?

# %%
scipy.stats.kstest?

# %%
scipy.stats.ks_2samp?

# %%
scipy.stats.anderson?

# %% [markdown]
# ## normal vs normal

# %%
np.random.seed(999)
dist_n = np.random.randn(1000)
scipy.stats.anderson(dist_n, dist='norm')
# Out:
# AndersonResult(statistic=0.26231814126674635, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
#generate the distribution
dist_n = np.random.randn(1000) # + 100

#test ad and ks. those are easy
print ("normal on normal", scipy.stats.kstest(dist_n,'norm'))
print ("normal on normal", scipy.stats.anderson(dist_n, dist='norm'))
print ("")
# Out:
# normal on normal KstestResult(statistic=0.016344431331899, pvalue=0.9521289020329357)
# normal on normal AndersonResult(statistic=0.26231814126674635, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %% [markdown]
# ## Poisson vs normal

# %%
np.random.poisson?

# %% [markdown]
# ### poisson w small mean vs standard normal

# %%
lam = 2
dist_p = np.random.poisson(lam, 1000)

print ("poisson on normal", scipy.stats.kstest(dist_p,'norm'))
print ("poisson on normal", scipy.stats.anderson(dist_p, dist='norm'))
print ("")
# Out:
# poisson on normal KstestResult(statistic=0.7023447460685429, pvalue=0.0)
# poisson on normal AndersonResult(statistic=26.579546015153937, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %% [markdown]
# ### poisson with large mean vs standard normal

# %%
dist_p = (np.random.poisson(100, 1000))
pl.hist(dist_p, label="Poisson")
pl.hist(dist_n, alpha=0.7)
pl.legend()

print ("poisson on normal", scipy.stats.kstest(dist_p,'norm'))
print ("poisson on normal", scipy.stats.anderson(dist_p, dist='norm'))
print ("") 

print (scipy.stats.anderson(dist_n, dist='norm'))
threshold = scipy.stats.anderson(dist_n, dist='norm')[1][scipy.stats.anderson(dist_n, dist='norm')[2]==[1.0]]
print (threshold)

##This sets a threshold: if the fit is good this is what the test should return
# Out:
# poisson on normal KstestResult(statistic=1.0, pvalue=0.0)
# poisson on normal AndersonResult(statistic=0.6622362040961889, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
#
# AndersonResult(statistic=0.26231814126674635, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
# [1.088]

# %%
dist_p = (np.random.poisson(100, 1000) - 100) * 0.1
pl.hist(dist_p, label="Poisson")
pl.hist(dist_n, alpha=0.7)
pl.legend()

print ("poisson on normal", scipy.stats.kstest(dist_p,'norm'))
print ("poisson on normal", scipy.stats.anderson(dist_p, dist='norm'))
print ("") 

print (scipy.stats.anderson(dist_n, dist='norm'))
threshold = scipy.stats.anderson(dist_n, dist='norm')[1][scipy.stats.anderson(dist_n, dist='norm')[2]==[1.0]]
print (threshold)

##This sets a threshold: if the fit is good this is what the test should return
# Out:
# poisson on normal KstestResult(statistic=0.048172162722971035, pvalue=0.018658273924315072)
# poisson on normal AndersonResult(statistic=0.8257736597652183, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
#
# AndersonResult(statistic=0.26231814126674635, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
# [1.088]

# %% [markdown]
# i will leave it to you to study the outputs in detail, but lets use the statistics.
#
# the statistics value will be **larger** if the distributions are **not** likely to be related.
# think about this in terms of rejection of the NULL hypothesis.
#
# #try writing down the null for each test and see if scipy manual agrees with you         (the manual spells out the Null)

# %% [markdown]
# the KL divergence is a little trickier: i have to pass it the values of the distribution at some x's: that means i have to pass it a **NORMALIZED HOSTOGRAM OF MY DISTRIBUTION**, i.e. derive a PDF from the data. we have done it before!
#
# i have to pass it a function for my comparison distribution evaluated at the x-values where my empirical distribution is evaluated.  not just the name of a distribution

# %%
dist_b = (np.random.binomial(200, 0.5, 1000) - 100) * 0.15
pl.hist(dist_b, label="binomial")
pl.hist(dist_n, alpha=0.7)
pl.legend()

print ("poisson on normal", scipy.stats.kstest(dist_b,'norm'))
print ("poisson on normal", scipy.stats.anderson(dist_b, dist='norm'))
print ("") 

print (scipy.stats.anderson(dist_n, dist='norm'))
threshold = scipy.stats.anderson(dist_b, dist='norm')[1][scipy.stats.anderson(dist_b, dist='norm')[2]==[5.0]]
print (threshold)

##This sets a threshold: if the fit is good this is what the test should return
# Out:
# poisson on normal KstestResult(statistic=0.06464477971207994, pvalue=0.00044661483756236464)
# poisson on normal AndersonResult(statistic=1.1703451664697013, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
#
# AndersonResult(statistic=0.26231814126674635, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
# [0.784]

# %%
distpdf_n, mybins_n, = np.histogram(dist_n, density=True)
distpdf_b, mybins_b, = np.histogram(dist_b, density=True)
distpdf_p, mybins_p, = np.histogram(dist_p, density=True)

#notice the extra comma on the left side of the '=' sign: 
#that tells numpy take the first two values returned, 
#and throw away the rest

# %% [markdown]
# then i have to pass it the functional form of a normal PDF, which is returned by the function scipy.stats.norm for example (a google search would have told you!)
# evaluated at the bin centers of the histogram from before

# %%
#get the bin centers
bincenters_n = mybins_n[:-1] + 0.5*(mybins_n[1] - mybins_n[0])
bincenters_b = mybins_b[:-1] + 0.5*(mybins_b[1] - mybins_b[0])
bincenters_p = mybins_p[:-1] + 0.5*(mybins_p[1] - mybins_p[0])
print ("normal on normal", 
    scipy.stats.entropy(distpdf_n, 
                            scipy.stats.norm.pdf(bincenters_n)) )
print ("poisson on normal", 
       scipy.stats.entropy(distpdf_p, 
                                scipy.stats.norm.pdf(bincenters_p)))

#you can interpret this as a distance: 
# it increases as the distributions diverge
# Out:
# normal on normal 0.00527211066211795
# poisson on normal 0.009179600084833575

# %% [markdown]
# #BINOMIAL

# %%
#to store the data i am generating an empty array of the size of the values of n i want to test. i do that with np.zeros which takes the length of the array as argument, and the data type as optional argument, but default is float, which is fine by me, so i do not need any argument other then the lenght 
narray = range(1,50,1)
ks_b = np.zeros(len(narray))
ad_b = np.zeros(len(narray))
kl_b = np.zeros(len(narray))
chi2_b = np.zeros(len(narray))

#then i put the tests in a for loop so that i can generate a distribution for given parameters once, 
#and run all tests against it
#now the valus that i want to plot depends on how i intend to describe the plot, and viceversa. 

#here is one way to plot it, knowing the values i get for the tests when 
#i throw in a poisson distribution with low l and compare it with a gaussian and 
#assuming that that is a vary bad match

for i,n in enumerate(narray):
    p=0.1 #parameter for the binomial, my arbitrary choice
    #generate the distribution
    dist = np.random.binomial(n, 0.5, 1000)
    #run the tests. 
    ks_b[i] = scipy.stats.kstest(dist,'norm')[0]
    #print scipy.stats.kstest(dist,'norm')
    #print scipy.stats.anderson(dist, dist='norm')
    ad_b[i] = scipy.stats.anderson(dist, dist='norm')[0]
    #ad_b[i] = ad_b[i] / ad_b[0]
    #print ad_b[i]
  
    # for KL and Pearson's chisq I have to simulate the normal distribution as well
    mybins=np.linspace(min(dist),max(dist), 10) 
    bincenters = mybins[:-1]+0.5*(mybins[1]-mybins[0])

    #when i was coding this up something was wrong. i put some plots in to figure out what... just so you know.
    #if i%10 == 0: 
    #    pl.hist(dist, bins=mybins)
    #    pl.plot(bincenters, scipy.stats.norm.pdf(bincenters)*1000)
    kl_b [i] =  scipy.stats.entropy(np.histogram(dist, bins=mybins)[0], scipy.stats.norm.pdf(bincenters)+n)

# %% [markdown]
# #this is just one way to plot it. get creative and find the best way to show your result!
# then give me a cell in which you write a caption for the figures you plot. think about how the captions are written in the paper  you have to read for this week assignment: a caption must describe the plot sufficiently well that i do not need to read the paper to understand it. though it will generally lack details of the how and why you see what you see. those are in the paper

# %%
fig = pl.figure(figsize = (15,5))
fig.add_subplot(131)
pl.plot(narray, ks_b, label='KS')
pl.legend()

fig.add_subplot(132)
pl.plot(narray, ad_b,  label='AD')
pl.plot([narray[0], narray[-1]],[threshold, threshold])
pl.plot()
pl.plot()
pl.legend()

fig.add_subplot(133)
pl.plot(narray, kl_b, label='K-L ')

pl.legend()

# %% [markdown]
# ##WRITE A CAPTION HERE IN THIS CELL..

# %% [markdown]
# #POISSON

# %%
#to store the data i am generating an empty array of the size of the values of n i want to test. i do that with np.zeros which takes the length of the array as argument, and the data type as optional argument, but default is float, which is fine by me, so i do not need any argument other then the lenght 
narray = range(1,50,1)
ks_b = np.zeros(len(narray))
ad_b = np.zeros(len(narray))
kl_b = np.zeros(len(narray))
chi2_b = np.zeros(len(narray))

#then i put the tests in a for loop so that i can generate a distribution for given parameters once, 
#and run all tests against it
#now the valus that i want to plot depends on how i intend to describe the plot, and viceversa. 

#here is one way to plot it, knowing the values i get for the tests when 
#i throw in a poisson distribution with low l and compare it with a gaussian and 
#assuming that that is a vary bad match

for i,n in enumerate(narray):
    p=0.1 #parameter for the binomial, my arbitrary choice
    #generate the distribution
    dist = np.random.poisson(n, 1000)
    #run the tests. 
    ks_b[i] = scipy.stats.kstest(dist,'norm')[0]
    #print scipy.stats.kstest(dist,'norm')
    #print scipy.stats.anderson(dist, dist='norm')
    ad_b[i] = scipy.stats.anderson(dist, dist='norm')[0]
    #ad_b[i] = ad_b[i] / ad_b[0]
    #print ad_b[i]
  
    # for KL and Pearson's chisq I have to simulate the normal distribution as well
    mybins=np.linspace(min(dist),max(dist), 10) 
    bincenters = mybins[:-1]+0.5*(mybins[1]-mybins[0])

    #when i was coding this up something was wrong. i put some plots in to figure out what... just so you know.
    #if i%10 == 0: 
    #    pl.hist(dist, bins=mybins)
    #    pl.plot(bincenters, scipy.stats.norm.pdf(bincenters)*1000)
    kl_b [i] =  scipy.stats.entropy(np.histogram(dist, bins=mybins)[0], scipy.stats.norm.pdf(bincenters)+n)

# %%
fig = pl.figure(figsize = (15,5))
fig.add_subplot(131)
pl.plot(narray, ks_b, label='KS')
pl.legend()

fig.add_subplot(132)
pl.plot(narray, ad_b,  label='AD')
pl.plot([narray[0], narray[-1]],[threshold, threshold])
pl.plot()
pl.plot()
pl.legend()

fig.add_subplot(133)
pl.plot(narray, kl_b, label='K-L ')

pl.legend()

# %% [markdown]
# ##TOTALLY OPTIONAL fun with KL: the KL divergence is a measure of how much approximation you have to do to represent one distribution with the other. you can see what it looks point by point, before you integrate and get a single distance number

# %%
pl.figure(figsize=(15,15))

p = lambda x, mu : scipy.stats.distributions.poisson.pmf(x,mu)
q = lambda x, mu : scipy.stats.distributions.norm.pdf(x-mu)
c = lambda x, mu : scipy.stats.distributions.chi2.pdf(x, df=mu)
f = lambda x, mu : scipy.stats.distributions.f.pdf(x,100,100)

Dkl = lambda x ,mu, p :  p(x, mu)* np.log10(q(x, mu)) + p(x, mu) *np.log10(p(x, mu))

def model(x) : 
    return 1./(s*np.sqrt(2*np.pi))*exp(-((x-m)/2./2./s)**2)

x=np.linspace(-10,10,100)
pl.plot(x, q(x,1), label='norm')
pl.plot(x, p(x,1), label='poisson')
pl.plot(x, Dkl(x, 1, p), '-.', label = 'KL - poisson')

#print np.nansum(Dkl(np.linspace(0,30,1000), 1, p))


pl.plot(x, c(x,1), label='f')
pl.plot(x,Dkl(x, 1, c), '--', label = 'KL - chi2')



#print np.nansum(Dkl(np.linspace(0,30,1000), 1, c))


pl.plot(x, f(x,1), label='F')
pl.plot(x,Dkl(x, 1, f), '--', label = 'KL - F')

#print np.nansum(Dkl(np.linspace(0,30,1000), 1, f))
bins = np.arange(0, 99, 10)

pl.xlim(0,10)
pl.legend( fontsize = 20)
# Out:
# //anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log10
#
# //anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in multiply

# %% [markdown]
# # 2-sample versions of the KS test

# %%
r1 = np.random.randn(100)
p1 = np.random.poisson(lam=2, size=100)
scipy.stats.ks_2samp(r1, p1)
